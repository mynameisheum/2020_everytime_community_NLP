# %%
ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FC98-4D75
#
#  C:\Users\bad_w 디렉터리
#
# 2020-12-01  오후 02:52    <DIR>          .
# 2020-12-01  오후 02:52    <DIR>          ..
# 2020-11-07  오후 07:10    <DIR>          .conda
# 2020-07-06  오후 05:08    <DIR>          .idlerc
# 2020-12-01  오후 02:52    <DIR>          .ipynb_checkpoints
# 2020-11-07  오후 07:18    <DIR>          .ipython
# 2020-11-07  오후 07:20    <DIR>          .jupyter
# 2020-11-07  오후 07:19    <DIR>          .keras
# 2020-12-01  오후 02:46    <DIR>          .matplotlib
# 2020-07-08  오후 04:48    <DIR>          .pylint.d
# 2020-12-01  오후 02:46    <DIR>          .spyder-py3
# 2020-07-06  오후 05:20    <DIR>          .vscode
# 2020-11-20  오후 07:18    <DIR>          3D Objects
# 2020-11-07  오후 08:12         9,721,344 chromedriver.exe
# 2020-11-20  오후 07:18    <DIR>          Contacts
# 2020-11-11  오후 06:39             4,375 debug.log
# 2020-12-01  오후 01:26    <DIR>          Desktop
# 2020-11-20  오후 07:18    <DIR>          Documents
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
# from konlpy.tag import Kkma
import openpyxl

# %%
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

# %%
driver.get('https://kangwon.everytime.kr/login')

# %%
# driver.get('https://kangwon.everytime.kr/login')
driver.find_element_by_name('userid').send_keys('tjdgma95')
driver.find_element_by_name('password').send_keys('132456')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

# %%
time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()
#sheet > ul > li.none > a
# //*[@id="submenu"]/div/div[9]/ul/li[2]/a
# //*[@id="submenu"]/div/div[2]/ul/li[1]/a

# %%
#container > div.wrap.articles > div.pagination > a

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

# %%
# //*[@id="container"]/div[2]/article[{}]/a/p
# https://kangwon.everytime.kr/380617

# %%
for page_roof in range(20,39):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-20-38page.xlsx')
excel_file.close()
# Out:
# page number :  21
# text_list_num :  1
#
# page number :  21
# text_list_num :  1
# 익명
# page number :  21
# text_list_num :  1
# 12/01 18:09
# page number :  21
# text_list_num :  1
# 달 보이시는분
# page number :  21
# text_list_num :  1
# 제발요.. 달이 안보여요 과제인데 ;;
# page number :  21
# text_list_num :  1
# 네~ 보여드렸습니다
# page number :  21
# text_list_num :  1
# 천문학과임??
# page number :  21
# text_list_num :  1
# 어제 찍엇는데 보름달
# page number :  21
# text_list_num :  1
# 오늘 음력 17일이니까 자정에 남동쪽하늘 보세요 6시에는 안 보이는 게 정상임
# page number :  21
# text_list_num :  2
#
# page number :  21
# text_list_num :  2
# 익명
# page number :  21
# text_list_num :  2
# 12/01 18:09
# page number :  21
# text_list_num :  2
# 달 보이시는분
# page number :  21
# text_list_num :  2
# 제발요.. 달이 안보여요 과제인데 ;;
# page number :  21
# text_list_num :  2
# 네~ 보여드렸습니다
# page number :  21
# text_list_num :  2
# 천문학과임??
# page number :  21
# text_list_num :  2
# 어제 찍엇는데 보름달
# page number :  21
# text_list_num :  2
# ...

# %%
# driver.quit()
# driver.get('https://kangwon.everytime.kr/380617/p/39')

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('tjdgma95')
driver.find_element_by_name('password').send_keys('132456')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/51')
time.sleep(5)

for page_roof in range(51,69):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-51-68page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  51
# text_list_num :  1
#
# page number :  51
# text_list_num :  1
# 익명
# page number :  51
# text_list_num :  1
# 12/01 15:05
# page number :  51
# text_list_num :  1
# 배속이 답답하다 해도
# page number :  51
# text_list_num :  1
# 상식적으로 그게 안된다는걸 왜 모르는거냐교수님 속도 답답해서 돌리는데 뭐가 문제냐는것도 적반하장이네ㅋㅋㅋㅋㅋ
# page number :  51
# text_list_num :  2
#
# page number :  51
# text_list_num :  2
# 익명
# page number :  51
# text_list_num :  2
# 12/01 15:05
# page number :  51
# text_list_num :  2
# 배속말이야
# page number :  51
# text_list_num :  2
# 강의를 총 3번 봤다쳐처음에 정상 속도로 시청하고그 후에는 배속으로 보는 건 허용한다 했잖아?처음에 배속하고그 후에는 정상 속도로 시청하는건 뭐야?
# page number :  51
# text_list_num :  2
# 왜 그런짓을
# page number :  51
# text_list_num :  2
# 그건 나가리지
# page number :  51
# text_list_num :  2
# 뭐하는사람임?
# page number :  51
# text_list_num :  2
# 진정해.. 그저 호기심에 물어본거야 나는 배속 안했다구 😓
# page number :  51
# text_list_num :  2
# 출석기간 이내면 괜찮을거 같은데???
# page number :  51
# text_list_num :  2
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/69')
time.sleep(5)

for page_roof in range(69,87):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-69-86page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  69
# text_list_num :  1
#
# page number :  69
# text_list_num :  1
# 익명
# page number :  69
# text_list_num :  1
# 12/01 10:00
# page number :  69
# text_list_num :  1
# 과수업 비대면 된 줄 모르고
# page number :  69
# text_list_num :  1
# 학교왔다가 돌아가는중아침운동했네 쒸불
# page number :  69
# text_list_num :  2
#
# page number :  69
# text_list_num :  2
# 익명
# page number :  69
# text_list_num :  2
# 12/01 09:56
# page number :  69
# text_list_num :  2
# 천지관 학식메뉴도 백록이랑 똑같나?
# page number :  69
# text_list_num :  2
# ㅈㄱㄴ
# page number :  69
# text_list_num :  2
# ㄴㄴ
# page number :  69
# text_list_num :  2
# 뭐뭐나옴? 한식
# page number :  69
# text_list_num :  2
# 생활협동조합 홈페이지가봐
# page number :  69
# text_list_num :  2
# 한식메뉴는 백록이랑 똑같이 나오는데? 잘못본건가
# page number :  69
# text_list_num :  2
# 고치돈이 천지관꺼임 다른 메뉴들도 달라
# page number :  69
# text_list_num :  2
# 한식메누 다른거있음?
# page number :  69
# text_list_num :  3
#
# page number :  69
# text_list_num :  3
# 익명
# page number :  69
# text_list_num :  3
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/69')
time.sleep(5)

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/106')
time.sleep(5)

for page_roof in range(106,124):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-106-123page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  106
# text_list_num :  1
#
# page number :  106
# text_list_num :  1
# 익명
# page number :  106
# text_list_num :  1
# 11/30 18:19
# page number :  106
# text_list_num :  1
# 미쳤나봐 과제 마감된지 며칠 지났는데 존재 자체를 지금알음
# page number :  106
# text_list_num :  1
# ㅠㅠㅠㅠ...
# page number :  106
# text_list_num :  1
# 오 나도
# page number :  106
# text_list_num :  1
# 차라리 모르는게 나았지.. ㅋㅋ큐ㅠㅠㅠ 나도 그런거있음
# page number :  106
# text_list_num :  2
#
# page number :  106
# text_list_num :  2
# 익명
# page number :  106
# text_list_num :  2
# 11/30 18:14
# page number :  106
# text_list_num :  2
# 오늘 후문 대판 열었어?
# page number :  106
# text_list_num :  2
# 가려구 ㅈㄱㄴ
# page number :  106
# text_list_num :  2
# 나도알려주
# page number :  106
# text_list_num :  2
# 삭제된 댓글입니다.
# page number :  106
# text_list_num :  2
# 감사링
# page number :  106
# text_list_num :  3
#
# page number :  106
# text_list_num :  3
# 저녁밥빌런
# page number :  106
# text_list_num :  3
# 11/30 18:12
# page number :  106
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/124')
time.sleep(5)

for page_roof in range(124,142):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-124-141page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  124
# text_list_num :  1
#
# page number :  124
# text_list_num :  1
# 익명
# page number :  124
# text_list_num :  1
# 11/30 10:36
# page number :  124
# text_list_num :  1
# 애인있는 애들아
# page number :  124
# text_list_num :  1
# 너네 그 사람이랑 사귀기 잘했단 생각이 들때가 언제야?난 모솔이라 댓글보면서 대리만족하게 자랑좀 하고가줘...
# page number :  124
# text_list_num :  1
# 나를 조건없이 사랑해줄때...? 진짜 그냥 나를 좋아한다는 느낌 받을때
# page number :  124
# text_list_num :  1
# 진짜 이런 사람은 또 못 찾을 것 같아. 근ㄷ 상대방도 나같은 사람 또 못 찾을 것 같아서 나한테 둘도 없는 사람처럼 대한대
# page number :  124
# text_list_num :  1
# 글 지우지말고 1년만 기다려. 생기고올게
# page number :  124
# text_list_num :  1
# 1년뒤엔 생길거란 너의 자만
# page number :  124
# text_list_num :  1
# 익7 훗
# page number :  124
# text_list_num :  1
# 날 너무 좋아해서 울 때
# page number :  124
# text_list_num :  1
# 날 엄청귀여워해줄때🥰 공주가된거같아 행복해
# page number :  124
# text_list_num :  1
# 이유 없이 날 사랑할때 그냥 나라서 사랑해줄때
# page number :  124
# text_list_num :  2
#
# page number :  124
# text_list_num :  2
# 익명
# page number :  124
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/142')
time.sleep(5)

for page_roof in range(142,160):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-142-159page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  142
# text_list_num :  1
#
# page number :  142
# text_list_num :  1
# 익명
# page number :  142
# text_list_num :  1
# 11/29 18:40
# page number :  142
# text_list_num :  1
# 봉사활동 독후감 질문 있어요!!ㅠ
# page number :  142
# text_list_num :  1
# 봉사은행에 들어가서 언제까지 적어야 하는지, 뭘 적어야 하는지에 대해서 알고 싶은데 잘 못찾겠어서요ㅠㅠ 아시는 분 계신가요ㅠㅠ
# page number :  142
# text_list_num :  2
#
# page number :  142
# text_list_num :  2
# 익명
# page number :  142
# text_list_num :  2
# 11/29 18:39
# page number :  142
# text_list_num :  2
# 근로 정말 개꿀이야
# page number :  142
# text_list_num :  2
# 말해뭐해... 물론 근로지 바이 근로지긴한데 나는 할일 많은 편인곳인데도 꿀 소리가 절로 나옴 걍 앉아서 과제하다가 심부름하고 할일 조금 하고 과제하다 퇴근일단 무조건 신청해봐 얘들아
# page number :  142
# text_list_num :  2
# 근장은 뭘 하던지 꿀인것 같음 근데 과사 이런데는 좀 별로였음
# page number :  142
# text_list_num :  2
# 내가 과사 비슷한곳이야.. 단대 안 ㅋㅋㅋ 근데 다른 험난한 알바들에 굴림당하다 와서 그런지 그냥 좋다,,,
# page number :  142
# text_list_num :  2
# 본인 과 아니면 학교 어떤거든 ㄱㅊ 본인 과 조교쌤이 착하시다 그래도 ㄱㅊ 근데 그럴 가능성이..너무 낮아
# page number :  142
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/160')
time.sleep(5)

for page_roof in range(160,178):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-160-177page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  161
# text_list_num :  1
#
# page number :  161
# text_list_num :  1
# 익명
# page number :  161
# text_list_num :  1
# 11/28 21:25
# page number :  161
# text_list_num :  1
# 솔직하게2
# page number :  161
# text_list_num :  1
# 내가 30살에 이 정도 연봉은 충분히 받을 것 같다.1. 세전  3000만 이하2. 세전 4000만 이하3. 세전 5000만 이하4. 세전 6000만 이하5. 세전 6000만 이상
# page number :  161
# text_list_num :  1
# 2
# page number :  161
# text_list_num :  1
# 5
# page number :  161
# text_list_num :  1
# 1억이상받을거임
# page number :  161
# text_list_num :  1
# 6.무직
# page number :  161
# text_list_num :  1
# 힘내고
# page number :  161
# text_list_num :  1
# 2부터는 대기업인데......  학교 통계 보면 졸업생 중 2~3%네ㄷㄷㄷ
# page number :  161
# text_list_num :  1
# 통계 어딨음?
# page number :  161
# text_list_num :  1
# 꿈은 크면 좋지..
# page number :  161
# text_list_num :  1
# 꿈 물어본 거 아닌데..
# page number :  161
# text_list_num :  1
# 팩트)강대생 95%는 1번 이하다
# page number :  161
# text_list_num :  1
# 통계자료라도 있음?
# page number :  161
# text_list_num :  1
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/178')
time.sleep(5)

for page_roof in range(178,196):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-178-195page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  178
# text_list_num :  1
#
# page number :  178
# text_list_num :  1
# 익명
# page number :  178
# text_list_num :  1
# 11/27 23:40
# page number :  178
# text_list_num :  1
# 이거 뭐임?
# page number :  178
# text_list_num :  1
# 갑자기 연결됐어 ;;검색해도 안 나옴 무서워서 안 눌러봄
# page number :  178
# text_list_num :  1
# CD 넣는곳도 없는데 왜 인식됐지..?
# page number :  178
# text_list_num :  1
# 삭제된 댓글입니다.
# page number :  178
# text_list_num :  1
# 모르니까 물어봤지
# page number :  178
# text_list_num :  1
# 삭제된 댓글입니다.
# page number :  178
# text_list_num :  1
# 다시 사라졌어
# page number :  178
# text_list_num :  1
# 랜카드 꽃음?
# page number :  178
# text_list_num :  1
# 랜카드? 랜선 말하는거?
# page number :  178
# text_list_num :  1
# 저거 떳을때 뭐 usb건 블루투스를 연결하건 뭐 한거있어여?
# page number :  178
# text_list_num :  2
#
# page number :  178
# text_list_num :  2
# 익명
# page number :  178
# text_list_num :  2
# 11/27 23:39
# page number :  178
# text_list_num :  2
# 내가 하고싶은건 뭘까
# page number :  178
# text_list_num :  2
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/223')
time.sleep(5)

for page_roof in range(223,241):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-223-240page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  223
# text_list_num :  1
#
# page number :  223
# text_list_num :  1
# 익명
# page number :  223
# text_list_num :  1
# 11/27 13:15
# page number :  223
# text_list_num :  1
# 걍 학교 임직원들 다 걸리고 자녀들까지 걸려버렸으면ㅌㅋ
# page number :  223
# text_list_num :  1
# 그래야 정신차리지
# page number :  223
# text_list_num :  1
# 우리 교수님 제발.....
# page number :  223
# text_list_num :  1
# 전염병 가지고 가족까지 건드리는건 아니라고 본다...
# page number :  223
# text_list_num :  1
# 작성자 선넘...
# page number :  223
# text_list_num :  1
# 답답한 심정은 알겠는데 선 넘지 마라
# page number :  223
# text_list_num :  1
# 글삭해라
# page number :  223
# text_list_num :  1
# 하... 아무리 그래도 이런생각을 한다는게 정말 놀랍다
# page number :  223
# text_list_num :  2
#
# page number :  223
# text_list_num :  2
# 익명
# page number :  223
# text_list_num :  2
# 11/27 13:15
# page number :  223
# text_list_num :  2
# 올해 총학이나 내년 총학이나..;;
# page number :  223
# text_list_num :  2
# ...

# %%
# chromedriver ='./chromedriver.exe'
# driver = webdriver.Chrome(chromedriver)

# driver.get('https://kangwon.everytime.kr/login')

# driver.find_element_by_name('userid').send_keys('ukcnggg')
# driver.find_element_by_name('password').send_keys('08217kjh')
# driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

# time.sleep(5)
# driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
# time.sleep(5)
# driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

# time.sleep(5)
# driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
# time.sleep(5)

# driver.get('https://kangwon.everytime.kr/380617/p/241')
# time.sleep(5)

# %%
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/280')
time.sleep(5)

for page_roof in range(280,280+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-280page.xlsx')
excel_file.close()

driver.quit()
# Out:
# page number :  281
# text_list_num :  1
#
# page number :  281
# text_list_num :  1
# 익명
# page number :  281
# text_list_num :  1
# 11/26 18:03
# page number :  281
# text_list_num :  1
# 아이폰 5s
# page number :  281
# text_list_num :  1
# 액정 수리 어디서 하나요?(혹시 수리비용도 알려주시면 감사합니다)
# page number :  281
# text_list_num :  1
# 8s 팔아요
# page number :  281
# text_list_num :  1
# 쓰고있어
# page number :  281
# text_list_num :  1
# 아이폰 5s : 그냥 죽....여....줘........
# page number :  281
# text_list_num :  1
# 안돼 일어나
# page number :  281
# text_list_num :  1
# 5s 수리해야될정도면 그냥 폰을 바꾸는게 나을듯 ..
# page number :  281
# text_list_num :  1
# 예전에 쓰던거 액정만 금가서 수리하고 다시 쓰고 싶어서ㅠ
# page number :  281
# text_list_num :  1
# 음 5s가 정확히 얼마일지는 모르겠지만 한달전쯤에 나 11일반 액정수리하는데 302000이었어 ㅜㅠ 가로수길은 264000인데 지네는 협력업체라서 돈 더받는대 .. 애플 공홈들어가면 가격 나와있으니까 한 번 봐바
# page number :  281
# text_list_num :  1
# 공홈 넘 비싸 춘천 가게에서 5만원에 해준다는데..거기 괜찮겠지?
# page number :  281
# text_list_num :  1
# 너 수리하고 바로 폰 팔거아니면 절대 사설에서 하지마 진짜 200프로 후회함
# ...

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/298')
time.sleep(5)

for page_roof in range(298,298+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-298page.xlsx')
excel_file.close()

driver.quit()

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/316')
time.sleep(5)

for page_roof in range(316,316+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-316page.xlsx')
excel_file.close()

driver.quit()

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/334')
time.sleep(5)

for page_roof in range(334,334+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-334page.xlsx')
excel_file.close()

driver.quit()

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/352')
time.sleep(5)

for page_roof in range(352,352+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-352page.xlsx')
excel_file.close()

driver.quit()

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/370')
time.sleep(5)

for page_roof in range(370,370+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-370page.xlsx')
excel_file.close()

driver.quit()

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/388')
time.sleep(5)

for page_roof in range(388,388+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-388page.xlsx')
excel_file.close()

driver.quit()

# %%
chromedriver ='./chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://kangwon.everytime.kr/login')

driver.find_element_by_name('userid').send_keys('ukcnggg')
driver.find_element_by_name('password').send_keys('08217kjh')
driver.find_element_by_xpath('//*[@id="container"]/form/p[3]/input').send_keys(Keys.RETURN)

time.sleep(5)
driver.find_element_by_xpath('//*[@id="submenu"]/div/div[2]/ul/li[1]/a').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="sheet"]/ul/li[3]').click()

time.sleep(5)
driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a').click()# 첫장
time.sleep(5)

driver.get('https://kangwon.everytime.kr/380617/p/406')
time.sleep(5)

for page_roof in range(406,406+18):
    
    if page_roof % 10 == 0:
        driver.get('https://kangwon.everytime.kr/380617/p/{}'.format(page_roof))
        time.sleep(5)
        
        for text_list_num in range(1,21):
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)
            
            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof+1)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)
            
        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
            
    else:  
        for text_list_num in range(1,21):

    #         driver.find_element_by_css_selector('#container > div.wrap.articles > article:nth-child({}) > a > p'.format(text_list_num)).click()
            driver.find_element_by_xpath('//*[@id="container"]/div[2]/article[{}]/a/h2'.format(text_list_num)).click()
            time.sleep(5)

            res = driver.page_source
            soup = BeautifulSoup(res,'html.parser')

            texts = soup.select('.large')
            times = soup.select('.medium')


            for text in texts:

                excel_sheet.append([text.get_text()])
                print('page number : ',page_roof)
                print('text_list_num : ',text_list_num)
                print(text.get_text())

            driver.back()
            time.sleep(5)


        driver.find_element_by_css_selector('#container > div.wrap.articles > div.pagination > a.next').click()
        time.sleep(5)
    

excel_file.save('everytime-free-406page.xlsx')
excel_file.close()

driver.quit()
